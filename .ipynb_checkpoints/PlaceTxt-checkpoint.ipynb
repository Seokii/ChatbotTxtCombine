# %%
import os

# %%
dir = 'data/'
outfile_name = "combineData/PlaceTxt.txt"

# %%
out_file = open(outfile_name, 'w')
files = os.listdir(dir)

# %%
for filename in files:
    if ".txt" not in filename:
        continue
    file = open(dir + filename)
    for line in file:
        if ("장소" in line) and ("0" in line):
            out_file.write(line.replace('0', '3'))
        elif ("장소" in line) and ("1" in line):
            out_file.write(line.replace('1', '3'))
        elif ("장소" in line) and ("2" in line):
            out_file.write(line.replace('2', '3'))
        elif ("장소" in line) and ("3" in line):
            out_file.write(line.replace('3', '3'))
        elif ("장소" in line) and ("4" in line):
            out_file.write(line.replace('4', '3'))
        elif ("장소" in line) and ("5" in line):
            out_file.write(line.replace('5', '3'))
        elif ("장소" in line) and ("6" in line):
            out_file.write(line.replace('6', '3'))
        elif ("위치" in line) and ("0" in line):
            out_file.write(line.replace('0', '3'))
        elif ("위치" in line) and ("1" in line):
            out_file.write(line.replace('1', '3'))
        elif ("위치" in line) and ("2" in line):
            out_file.write(line.replace('2', '3'))
        elif ("위치" in line) and ("3" in line):
            out_file.write(line.replace('3', '3'))
        elif ("위치" in line) and ("4" in line):
            out_file.write(line.replace('4', '3'))
        elif ("위치" in line) and ("5" in line):
            out_file.write(line.replace('5', '3'))
        elif ("위치" in line) and ("6" in line):
            out_file.write(line.replace('6', '3'))
        if ("어디" in line) and ("0" in line):
            out_file.write(line.replace('0', '3'))
        elif ("어디" in line) and ("1" in line):
            out_file.write(line.replace('1', '3'))
        elif ("어디" in line) and ("2" in line):
            out_file.write(line.replace('2', '3'))
        elif ("어디" in line) and ("3" in line):
            out_file.write(line.replace('3', '3'))
        elif ("어디" in line) and ("4" in line):
            out_file.write(line.replace('4', '3'))
        elif ("어디" in line) and ("5" in line):
            out_file.write(line.replace('5', '3'))
        elif ("어디" in line) and ("6" in line):
            out_file.write(line.replace('6', '3'))
        elif ("장소" in line) and ("공포" in line):
            out_file.write(line.replace('공포', '3'))
        elif ("장소" in line) and ("놀람" in line):
            out_file.write(line.replace('놀람', '3'))
        elif ("장소" in line) and ("분노" in line):
            out_file.write(line.replace('분노', '3'))    
        elif ("장소" in line) and ("슬픔" in line):
            out_file.write(line.replace('슬픔', '3'))
        elif ("장소" in line) and ("중립" in line):
            out_file.write(line.replace('중립', '3'))
        elif ("장소" in line) and ("행복" in line):
            out_file.write(line.replace('행복', '3'))
        elif ("장소" in line) and ("혐오" in line):
            out_file.write(line.replace('혐오', '3'))
        elif ("위치" in line) and ("공포" in line):
            out_file.write(line.replace('공포', '3'))
        elif ("위치" in line) and ("놀람" in line):
            out_file.write(line.replace('놀람', '3'))
        elif ("위치" in line) and ("분노" in line):
            out_file.write(line.replace('분노', '3'))    
        elif ("위치" in line) and ("슬픔" in line):
            out_file.write(line.replace('슬픔', '3'))
        elif ("위치" in line) and ("중립" in line):
            out_file.write(line.replace('중립', '3'))
        elif ("위치" in line) and ("행복" in line):
            out_file.write(line.replace('행복', '3'))
        elif ("위치" in line) and ("혐오" in line):
            out_file.write(line.replace('혐오', '3'))
        elif ("어디" in line) and ("공포" in line):
            out_file.write(line.replace('공포', '3'))
        elif ("어디" in line) and ("놀람" in line):
            out_file.write(line.replace('놀람', '3'))
        elif ("어디" in line) and ("분노" in line):
            out_file.write(line.replace('분노', '3'))    
        elif ("어디" in line) and ("슬픔" in line):
            out_file.write(line.replace('슬픔', '3'))
        elif ("어디" in line) and ("중립" in line):
            out_file.write(line.replace('중립', '3'))
        elif ("어디" in line) and ("행복" in line):
            out_file.write(line.replace('행복', '3'))
        elif ("어디" in line) and ("혐오" in line):
            out_file.write(line.replace('혐오', '3'))
    out_file.write('\n')
    file.close()
out_file.close()
